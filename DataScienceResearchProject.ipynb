# %% [markdown]
# Project Starts

# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   2
#   On-line CPU(s) list:    0,1
# Vendor ID:                GenuineIntel
#   Model name:             Intel(R) Xeon(R) CPU @ 2.00GHz
#     CPU family:           6
#     Model:                85
#     Thread(s) per core:   2
#     Core(s) per socket:   1
#     Socket(s):            1
#     Stepping:             3
#     BogoMIPS:             4000.31
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht sysc
#                           all nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xt
#                           opology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq
#                            ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt
# ...

# %%
# !cat /proc/meminfo | grep MemTotal
# Out:
# MemTotal:       13289424 kB

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.4 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !nvidia-smi
# Out:
# Sat Jun  7 14:11:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python --version
# Out:
# Python 3.11.13

# %%
import numpy
import scipy
import nltk
import torch
import transformers
#import gensim
import pandas

print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
print("NLTK version:", nltk.__version__)
print("Torch version:", torch.__version__)
print("Transformers version:", transformers.__version__)
print("SciPy version:", scipy.__version__)
#print("Gensim version:", gensim.__version__)
# Out:
# NumPy version: 2.0.2
# Pandas version: 2.2.2
# NLTK version: 3.9.1
# Torch version: 2.6.0+cu124
# Transformers version: 4.52.4
# SciPy version: 1.15.3

# %%
# !pip uninstall -y numpy scipy gensim pandas nltk transformers torch google-colab
# !pip install --no-cache-dir "pandas==2.2.2" "numpy<2.0,>=1.18.5" "scipy<1.14.0,>=1.7.0"  "nltk" "torch" "transformers"
#!pip install --no-cache-dir "pandas" "numpy"   "nltk" "torch" "transformers"

# import os
# os._exit(00)
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: scipy 1.14.1
# Uninstalling scipy-1.14.1:
#   Successfully uninstalled scipy-1.14.1
# WARNING: Skipping gensim as it is not installed.
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2
# Found existing installation: nltk 3.9.1
# Uninstalling nltk-3.9.1:
#   Successfully uninstalled nltk-3.9.1
# Found existing installation: transformers 4.50.0
# Uninstalling transformers-4.50.0:
#   Successfully uninstalled transformers-4.50.0
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: google-colab 1.0.0
# Uninstalling google-colab-1.0.0:
#   Successfully uninstalled google-colab-1.0.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 21.0 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y numpy pandas
# !pip install --upgrade --force-reinstall numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 60.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc 5.21.1 requires pandas>=0.24.0, which is not installed.
# plotnine 0.14.5 requires pandas>=2.2.0, which is not installed.
# dopamine-rl 4.1.2 requires pandas>=0.24.2, which is not installed.
# statsmodels 0.14.4 requires pandas!=2.1.0,>=1.4, which is not installed.
# accelerate 1.5.2 requires torch>=2.0.0, which is not installed.
# xarray 2025.1.2 requires pandas>=2.1, which is not installed.
# ...

# %%
print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
# Out:
# NumPy version: 2.0.2
# Pandas version: 2.2.2

# %%
import numpy
import scipy
import nltk
import torch
import transformers
#import gensim
import pandas

print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
print("NLTK version:", nltk.__version__)
print("Torch version:", torch.__version__)
print("Transformers version:", transformers.__version__)
print("SciPy version:", scipy.__version__)
#print("Gensim version:", gensim.__version__)
# Out:
# NumPy version: 2.0.2
# Pandas version: 2.2.2
# NLTK version: 3.9.1
# Torch version: 2.6.0+cu124
# Transformers version: 4.50.0
# SciPy version: 1.14.1

# %% [markdown]
# This section is to retrieve the dataset from github and display first few rows of dataset.

# %%
import pandas as pd

# URL of the raw CSV file on GitHub
url = 'https://media.githubusercontent.com/media/tarsvini/Data-Science-Project/refs/heads/main/All_Beauty.csv?token=AEHKG7BVI6KKUA6VCIN3WRDHTITRO'

# Read the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
#print(df.head())

from IPython.display import display

# Display the first few rows of the dataset in a nicer table
display(df.head())
# Out:
#    rating                                      title  \
# 0       5  Such a lovely scent but not overpowering.
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id                timestamp  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-05 14:08:48.923
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-04 18:10:55.070
# ...

# %% [markdown]
# Here, the code shows the info such as column name and its datatype.

# %%
# Get basic info (columns, data types, missing values)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701528 entries, 0 to 701527
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             701528 non-null  int64
#  1   title              701368 non-null  object
#  2   text               701316 non-null  object
#  3   images             701528 non-null  object
#  4   asin               701528 non-null  object
#  5   parent_asin        701528 non-null  object
#  6   user_id            701528 non-null  object
#  7   timestamp          701528 non-null  object
#  8   helpful_vote       701528 non-null  int64
#  9   verified_purchase  701528 non-null  bool
# dtypes: bool(1), int64(2), object(7)
# memory usage: 48.8+ MB
# None

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# Here, checking for missing values. These columns: title and text consist of null values.

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# rating                 0
# title                160
# text                 212
# images                 0
# asin                   0
# parent_asin            0
# user_id                0
# timestamp              0
# helpful_vote           0
# verified_purchase      0
# dtype: int64

# %% [markdown]
# So, im dropping the rows with missing values since the number of rows with missing values are 10% lesser compared to the dataset.

# %%
# Drop rows where 'text' or 'title' is missing
df.dropna(subset=['text', 'title'], inplace=True)

# %%
print(df.isnull().sum())
# Out:
# rating               0
# title                0
# text                 0
# images               0
# asin                 0
# parent_asin          0
# user_id              0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 701214 entries, 0 to 701527
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             701214 non-null  int64
#  1   title              701214 non-null  object
#  2   text               701214 non-null  object
#  3   images             701214 non-null  object
#  4   asin               701214 non-null  object
#  5   parent_asin        701214 non-null  object
#  6   user_id            701214 non-null  object
#  7   timestamp          701214 non-null  object
#  8   helpful_vote       701214 non-null  int64
#  9   verified_purchase  701214 non-null  bool
# dtypes: bool(1), int64(2), object(7)
# memory usage: 54.2+ MB
# None

# %% [markdown]
# Now, im only keeping relevant columns.

# %%
# Keep only relevant columns
df = df[['rating', 'title','text', 'helpful_vote','verified_purchase']]  # Modify as needed

# Save cleaned dataset
#df.to_csv("cleaned_All_Beauty.csv", index=False)

# Check final dataset
display(df.head())
# Out:
#    rating                                      title  \
# 0       5  Such a lovely scent but not overpowering.
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                                 text  helpful_vote  \
# 0  This spray is really nice. It smells really go...             0
# 1  This product does what I need it to do, I just...             1
# 2                          Smells good, feels great!             2
# 3                                     Felt synthetic             0
# 4                                            Love it             0
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %% [markdown]
# i filter the text column with hair keyword since my focus is sentiment analysis on haircare product reviews only.

# %%
# Filter rows where 'text' contains the word 'hair' (case insensitive)
df = df[df['text'].str.contains(r'\bhair\b', case=False, na=False)]
# Save cleaned dataset
#df.to_csv("cleaned_All_Beauty.csv", index=False)
print(f"Remaining rows after cleaning: {df.shape[0]}")
display(df.head())
# Out:
# Remaining rows after cleaning: 104595
#     rating                                              title  \
# 0        5          Such a lovely scent but not overpowering.
# 9        5                         Nice shampoo for the money
# 12       3                                            Just ok
# 13       5                           Good quality hair brush!
# 16       5  Quality hair iron, works perfectly to straight...
#
#                                                  text  helpful_vote  \
# 0   This spray is really nice. It smells really go...             0
# 9   I get Keratin treatments at the salon at least...             0
# 12  I try to get Keratin treatments every 3 months...             0
# 13  Really nice small brush. Made well, nice wood ...             0
# 16  This is a great hair straightener. Heats up qu...             0
#
#     verified_purchase
# 0                True
# 9               False
# 12              False
# 13              False
# 16              False

# %% [markdown]
# Next, im keeping only verified purchase.

# %%
# Keep only verified purchases
df = df[df['verified_purchase'] == True]  # If the column contains Boolean values
display(df.head())
print(f"Remaining rows after filtering: {df.shape[0]}")
# Out:
#     rating                                      title  \
# 0        5  Such a lovely scent but not overpowering.
# 31       5                                      Love!
# 32       1                       halo hair extensions
# 33       5                               clip rollers
# 65       5                     Such a nice spray mist
#
#                                                  text  helpful_vote  \
# 0   This spray is really nice. It smells really go...             0
# 31  Didn’t expect much but got a nice beautiful su...             0
# 32  This halo hair extension is simply put, garbag...             4
# 33  I purchased these to see if I could set my mom...             0
# 65  This spray smells amazing, it does claim to be...             0
#
#     verified_purchase
# 0                True
# 31               True
# 32               True
# 33               True
# 65               True
# Remaining rows after filtering: 92279

# %%
# Save cleaned dataset before removing stopwords
df.to_csv("cleaned_All_Beauty_before_NLP_processing.csv", index=False)

# %%
# import nltk
# import shutil

# # Remove all NLTK data (including punkt)
# nltk_data_path = "/root/nltk_data"  # Change this if needed
# shutil.rmtree(nltk_data_path, ignore_errors=True)
# print(f"Deleted NLTK data from: {nltk_data_path}")

# %% [markdown]
# Im cleaning dataset by converting to lowercase,removing special characters, remove extra spaces and tokenization.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Download 'punkt_tab'
nltk.download('punkt_tab')

# Initialize NLP tools
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W', ' ', text)  # Remove special characters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    tokens = word_tokenize(text)  # Tokenization
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]  # Lemmatization & Stopword removal
    return " ".join(tokens)

# Apply preprocessing
df['cleaned_review'] = df['text'].astype(str).apply(clean_text)

# Keep only relevant columns
#df = df[['rating', 'text', 'cleaned_review']]

# Save cleaned dataset
df.to_csv("cleaned_All_Beauty.csv", index=False)

# Display dataset preview
print(df.head())
print(f"Remaining rows after cleaning: {df.shape[0]}")

# Display dataset preview
print(df.head())
print(f"Remaining rows after cleaning: {df.shape[0]}")

# %%
display(df.head())

# %% [markdown]
# After filter with hair keyword and cleaning, now the dataset consists of 92279 rows. Next i need to explore by using topic modelling first.

# %% [markdown]
# Steps for Topic Modeling
# 1. Convert text into numerical form (Bag of Words or TF-IDF)
# 2. Apply LDA (Latent Dirichlet Allocation) to extract topics
# 3. Analyze the topics and visualize the results

# %% [markdown]
# What Each Topic Represents
#
# 1. Attempt -General usage of hair products, focusing on how they work over time.
# 2. Good - Wigs and hairpieces, emphasizing natural look, comfort, and style.
# 3. Coin - Cost-effectiveness and value for money (mentions of money, reviews, and time).
# 4. Conditioning -Shampoos and conditioners, focusing on scent, softness, and effectiveness.
# 5. Longer -Products related to hair length, such as extensions, clips, and styling products.

# %%
display(df.head())

# %% [markdown]
# in noticed some text are misclassified. VADER is optimized for short texts (like tweets) and may misinterpret long reviews.
# so instead of using VADER, i want to use other model such as BERT.

# %% [markdown]
# # Labelling sentiment

# %%
df = pd.read_csv('cleaned_All_Beauty.csv')

# %%
display(df.head(10))

# %%
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm  # For progress tracking

# Enable GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load the sentiment analysis model (fine-tuned on Amazon reviews)
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name).to(device)
model.eval()  # Set model to evaluation mode

# Load dataset
df = pd.read_csv("cleaned_All_Beauty.csv")  # Update with actual filename

# Extract reviews
reviews = df["text"].astype(str).tolist()
print(f"Total number of reviews: {len(reviews)}")

# Define batch processing function
def batch_sentiment_prediction(texts, batch_size=64):
    sentiments = []

    # Simplified sentiment mapping
    def map_to_three_classes(label):
        if label in [0, 1]:
            return "Negative"
        elif label == 2:
            return "Neutral"
        else:  # 3 or 4
            return "Positive"

    for i in tqdm(range(0, len(texts), batch_size), desc="Processing Batches"):
        batch_texts = texts[i:i + batch_size]
        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)

        with torch.no_grad():
            outputs = model(**inputs)

        batch_predictions = torch.argmax(outputs.logits, dim=1).cpu().numpy()
        sentiments.extend([map_to_three_classes(pred) for pred in batch_predictions])

    return sentiments

# Apply batch processing to the entire dataset
df['sentiment_label'] = batch_sentiment_prediction(df['text'].tolist())

# Save the labeled dataset
df.to_csv("labeled_All_Beauty_reviews.csv", index=False)
print("Sentiment labeling for all reviews completed and saved!")

# Display sample results
print(df[['text', 'sentiment_label']].head(10))
# Out:
# Using device: cuda
# Total number of reviews: 92279
# Processing Batches: 100%|██████████| 1442/1442 [30:06<00:00,  1.25s/it]
# Sentiment labeling for all reviews completed and saved!
#                                                 text sentiment_label
# 0  This spray is really nice. It smells really go...        Positive
# 1  Didn’t expect much but got a nice beautiful su...        Positive
# 2  This halo hair extension is simply put, garbag...        Negative
# 3  I purchased these to see if I could set my mom...        Positive
# 4  This spray smells amazing, it does claim to be...        Positive
# 5  Very surprised! I am please with first round o...        Positive
# 6  The headbands with the bow on top is soft and ...        Positive
# 7  My hairdresser recommended my husband get and ...        Positive
# 8  I purchased this for my shoulder length hair. ...         Neutral
# 9  Don’t get it!  My hair is falling out!  PLEASE...        Negative

# %%
import pandas as pd
df = pd.read_csv('labeled_All_Beauty_reviews.csv')

# %% [markdown]
# ### EDA

# %% [markdown]
# Check sentiment distribution to identify class imbalance

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("labeled_All_Beauty_reviews_3sentiments.csv")  # Update with actual filename

# Count sentiment labels
sentiment_counts = df["sentiment_label"].value_counts()

# Pie chart
plt.figure(figsize=(7, 7))
plt.pie(sentiment_counts.values, labels=sentiment_counts.index, autopct='%1.1f%%',
        colors=['#66c2a5','#fc8d62','#8da0cb','#e78ac3','#a6d854'], startangle=140)
plt.title("Sentiment Distribution in Haircare Product Reviews")
plt.show()

# %% [markdown]
# This dataset consists of highly positive reviews (63.3%). Majority of the reviews are Positive. This suggests that most customers are happy with their haircare products.
# Possible reasons: good product quality, effective results, strong brand loyalty. Negativity Exists but is lower (25.3%). Some users had bad experiences, but they are outnumbered by satisfied customers.
# Common issues: Product quality, shipping issues, misleading descriptions, allergic reactions. A small portion of users (11.4%) felt indifferent about the product. This  could indicate mixed experiences or lack of strong opinion.
# Positive (46.7%) is dominant, meaning the dataset is slightly imbalanced. Neutral & Negative sentiments have fewer samples, which might cause bias in model training.

# %% [markdown]
# Analyzing Top Words per Sentiment

# %% [markdown]
# Trigrams

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer



# Generate trigrams (3-grams) for each sentiment
sentiments = ['Positive', 'Negative', 'Neutral']
wordclouds = {}

# Load dataset
#df = pd.read_csv("labeled_All_Beauty_reviews.csv")  # Update with actual filename

for sentiment in sentiments:
    text = df[df['sentiment_label'] == sentiment]['cleaned_review'].dropna().tolist()

    # Convert text into trigrams
    vectorizer = CountVectorizer(ngram_range=(3, 3), stop_words="english")
    X = vectorizer.fit_transform(text)
    trigram_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().sum(axis=0)))

    # Generate word cloud from trigrams
    wordclouds[sentiment] = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(trigram_freq)

# Plot trigram word clouds
fig, axes = plt.subplots(3, 1, figsize=(24, 8))
for i, sentiment in enumerate(sentiments):
    axes[i].imshow(wordclouds[sentiment], interpolation='bilinear')
    axes[i].axis("off")
    axes[i].set_title(f"{sentiment} Trigram Word Cloud")

plt.show()

# %% [markdown]
# Positive Reviews:
#
# Common phrases: "make hair soft", "hair super soft", "love love love"
#
# Words like soft, love, quality suggest that customers appreciate the product's texture and quality.
#
#
# Negative Reviews:
#
# Common phrases: "hair look like", "shed like crazy", "waste money"
#
# Frequent words like "shed", "look like picture", "waste money" indicate dissatisfaction with product quality, shedding, and misleading expectations.
#
# Neutral Reviews:
#
# Common phrases: "br br update", "shoulder length hair", "hair feel like"
#
# The terms are more descriptive rather than extreme in sentiment. The word "update" might suggest neutral reviews are often informational or comparative.

# %% [markdown]
# Insights:Customers love soft and high-quality hair products.
#
# Negative reviews often highlight issues like excessive shedding and unrealistic expectations.
#
# Neutral reviews describe features like length, feel, and general experience.

# %% [markdown]
# # Model Development

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Load dataset
df = pd.read_csv("labeled_All_Beauty_reviews_3sentiments.csv")  # Update with actual filename

# Text features & labels
X = df["cleaned_review"].astype(str)  # Use preprocessed text
y = df["sentiment_label"]

# Convert text into TF-IDF vectors
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1,3))  # Using unigrams, bigrams, trigrams
X_tfidf = vectorizer.fit_transform(X)

# Split into train (80%) and test (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, stratify=y, random_state=42)

### 🔹 Train Linear SVC with Class Weighting
svc_model = LinearSVC(class_weight='balanced', random_state=42)
svc_model.fit(X_train, y_train)
svc_preds = svc_model.predict(X_test)

### 🔹 Train Multinomial Naïve Bayes (Disable Prior to Handle Imbalance)
nb_model = MultinomialNB(fit_prior=False)
nb_model.fit(X_train, y_train)
nb_preds = nb_model.predict(X_test)

# Evaluate Models
print("🔹 Linear SVC Performance:")
print(classification_report(y_test, svc_preds))

print("\n🔹 Naïve Bayes Performance:")
print(classification_report(y_test, nb_preds))
# Out:
# 🔹 Linear SVC Performance:
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.78      0.78      4665
#      Neutral       0.44      0.45      0.44      2110
#     Positive       0.90      0.89      0.89     11681
#
#     accuracy                           0.81     18456
#    macro avg       0.70      0.71      0.70     18456
# weighted avg       0.81      0.81      0.81     18456
#
#
# 🔹 Naïve Bayes Performance:
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.72      0.75      4665
#      Neutral       0.32      0.61      0.42      2110
#     Positive       0.91      0.79      0.84     11681
#
#     accuracy                           0.75     18456
#    macro avg       0.67      0.71      0.67     18456
# weighted avg       0.81      0.75      0.77     18456

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

# Load dataset
df = pd.read_csv("labeled_All_Beauty_reviews_3sentiments.csv")  # Ensure this file exists
X = df["cleaned_review"].astype(str)
y = df["sentiment_label"]

# TF-IDF
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 3))
X_tfidf = vectorizer.fit_transform(X)
print(vectorizer)
print(X_tfidf)
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, stratify=y, random_state=42
)

# 🔹 Linear SVC
svc_model = LinearSVC(class_weight='balanced', random_state=42)
svc_model.fit(X_train, y_train)
svc_preds = svc_model.predict(X_test)

# 🔹 Naïve Bayes
nb_model = MultinomialNB(fit_prior=False)
nb_model.fit(X_train, y_train)
nb_preds = nb_model.predict(X_test)

# Performance Reports
print("🔹 Linear SVC Performance:")
print(classification_report(y_test, svc_preds))

print("\n🔹 Naïve Bayes Performance:")
print(classification_report(y_test, nb_preds))

# --- 🔥 CONFUSION MATRICES ---
def plot_confusion(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    labels = sorted(y.unique())
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'{title} Confusion Matrix')
    plt.tight_layout()
    plt.show()

# Plot confusion matrices
plot_confusion(y_test, svc_preds, "Linear SVC")
plot_confusion(y_test, nb_preds, "Naïve Bayes")
# Out:
# TfidfVectorizer(max_features=10000, ngram_range=(1, 3))
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2414024 stored elements and shape (92279, 10000)>
#   Coords	Values
#   (0, 8113)	0.12089132671822413
#   (0, 7086)	0.24301602141469497
#   (0, 6076)	0.0917401771899455
#   (0, 7895)	0.09308724696349789
#   (0, 3238)	0.076668539597672
#   (0, 3200)	0.10347758430375574
#   (0, 2792)	0.10041862738158656
#   (0, 8938)	0.17254553953881832
#   (0, 7463)	0.11129126136686586
#   (0, 2702)	0.09197390277705633
#   (0, 5088)	0.06733573915491173
#   (0, 5996)	0.10268639457606836
#   (0, 5434)	0.1968578949784297
#   (0, 8704)	0.1200247507660179
#   (0, 3062)	0.07791596383375715
#   (0, 8580)	0.12071117014707708
#   (0, 9367)	0.11129904045166691
#   (0, 3515)	0.025705985528924585
#   (0, 5772)	0.13781002872207515
#   (0, 8644)	0.1557154955241892
#   (0, 1584)	0.22351131016973194
#   (0, 1010)	0.12450043444465249
#   (0, 1312)	0.15410304054229101
# ...

# %% [markdown]
# Interpretation

# %% [markdown]
# Linear SVC Performance
# -Overall accuracy: of the model is 81% and its good.
# Positive reviews: Precision 0.90, Recall 0.89, F1-score 0.89 → Very strong at predicting Positive sentiments.
#
# Negative reviews: Precision 0.77, Recall 0.78, F1-score 0.78 → Good performance for Negative reviews.
#
# Neutral reviews: Precision 0.44, Recall 0.45, F1-score 0.44 → Weak on Neutral reviews (common because Neutral is harder to capture, and often has fewer examples).

# %% [markdown]
# Naïve Bayes Performance
#
# Overall accuracy: 75% → Lower than SVC.
#
# Positive reviews: Still strong (Precision 0.91, Recall 0.79, F1-score 0.84).
#
# Negative reviews: Good (F1-score 0.75).
#
# Neutral reviews: Weak (F1-score 0.42, even lower precision than SVC).

# %% [markdown]
# in above code,naive bayes not handling  imbalance data well. So, will try to balance the dataset or use different models.

# %% [markdown]
# # BERT

# %% [markdown]
# light cleaning for BERT

# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize

# Download necessary NLTK data
nltk.download('punkt')

def clean_text_for_bert(text):
    text = text.lower()  # Lowercase
    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # Remove punctuation, keep only letters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Example: Apply to your DataFrame
df = pd.read_csv("labeled_All_Beauty_reviews_3sentiments.csv")  # Or your original file if needed
df['lightly_cleaned_review'] = df['text'].astype(str).apply(clean_text_for_bert)

# Save if needed
df.to_csv("labeled_bert_ready_All_Beauty.csv", index=False)

# Preview
print(df[['text', 'lightly_cleaned_review']].head())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                                 text  \
# 0  This spray is really nice. It smells really go...
# 1  Didn’t expect much but got a nice beautiful su...
# 2  This halo hair extension is simply put, garbag...
# 3  I purchased these to see if I could set my mom...
# 4  This spray smells amazing, it does claim to be...
#
#                               lightly_cleaned_review
# 0  this spray is really nice it smells really goo...
# 1  didnt expect much but got a nice beautiful sur...
# 2  this halo hair extension is simply put garbage...
# 3  i purchased these to see if i could set my mom...
# 4  this spray smells amazing it does claim to be ...

# %% [markdown]
# mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade transformers

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.3

# %%
#drive_model_dir = '/content/drive/MyDrive/UM_DS_2023/Project'  # Change to your desired path

import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments, EarlyStoppingCallback
import torch

# Load labeled dataset
df = pd.read_csv("labeled_bert_ready_All_Beauty.csv")
df = df[['lightly_cleaned_review', 'sentiment_label']].dropna()

# Encode labels
label_mapping = {label: idx for idx, label in enumerate(df['sentiment_label'].unique())}
df['label'] = df['sentiment_label'].map(label_mapping)
print(label_mapping)
# Out:
# {'Positive': 0, 'Negative': 1, 'Neutral': 2}

# %% [markdown]
# BERT -encoding, data split, tokenization, traning and evaluation.

# %%
# Define the directory in Google Drive where you want to save the model
drive_model_dir = '/content/drive/MyDrive/UM_DS_2023/Project'  # Change to your desired path

import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments, EarlyStoppingCallback
import torch

# Load labeled dataset
df = pd.read_csv("labeled_bert_ready_All_Beauty.csv")
df = df[['lightly_cleaned_review', 'sentiment_label']].dropna()

# Encode labels
label_mapping = {label: idx for idx, label in enumerate(df['sentiment_label'].unique())}
df['label'] = df['sentiment_label'].map(label_mapping)

# Train-test split
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['lightly_cleaned_review'], df['label'], test_size=0.2, random_state=42
)

# Tokenization
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, max_length=128)
val_encodings = tokenizer(list(val_texts), truncation=True, padding=True, max_length=128)

# Dataset preparation
class SentimentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

train_dataset = SentimentDataset(train_encodings, list(train_labels))
val_dataset = SentimentDataset(val_encodings, list(val_labels))

# Load model
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=len(label_mapping))

# Define evaluation metrics function
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(p):
    preds, labels = p
    preds = preds.argmax(axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    accuracy = accuracy_score(labels, preds)
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

# Training settings
training_args = TrainingArguments(
    output_dir='./results',
    eval_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=10,
    learning_rate=3e-5,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    save_total_limit=1,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,  # <<< moved here!
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],
)

# Train model
trainer.train()

# ---- 🔥 EVALUATION PART 🔥 ----

# Evaluate the model
results = trainer.evaluate()
print("Evaluation Results:", results)

# Full classification report
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict on validation set
predictions = trainer.predict(val_dataset)
y_pred = torch.argmax(torch.tensor(predictions.predictions), axis=1).numpy()
y_true = predictions.label_ids

# Print classification report
target_names = list(label_mapping.keys())  # To match original class names
print("\nClassification Report:")
report = classification_report(y_true, y_pred, target_names=target_names)
print(report)

# Save the classification report
with open(f'{drive_model_dir}/classification_report.txt', 'w') as f:
    f.write(report)

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names, cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig(f'{drive_model_dir}/confusion_matrix.png')  # Save the confusion matrix
plt.show()

# Save the model and tokenizer
model.save_pretrained(f'{drive_model_dir}/bert_model')
tokenizer.save_pretrained(f'{drive_model_dir}/bert_tokenizer')

# Save the results dictionary (optional)
import pickle
with open(f'{drive_model_dir}/training_results.pkl', 'wb') as f:
    pickle.dump(results, f)

print("\n✅ Model, tokenizer, results, and evaluation saved to Google Drive.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %% [markdown]
# Bi-LSTM

# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Set up drive directory
drive_model_dir = '/content/drive/MyDrive/UM_DS_2023/Project'  # Update with your path

# Load your dataset
df = pd.read_csv("labeled_bert_ready_All_Beauty.csv")
df = df[['lightly_cleaned_review', 'sentiment_label']].dropna()

# Encode labels
label_mapping = {label: idx for idx, label in enumerate(df['sentiment_label'].unique())}
df['label'] = df['sentiment_label'].map(label_mapping)

# Train-test split
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['lightly_cleaned_review'], df['label'], test_size=0.2, random_state=42
)

# Tokenization (You can use a simple tokenizer or implement your own)
vectorizer = CountVectorizer(max_features=5000, stop_words='english')
X_train = vectorizer.fit_transform(train_texts).toarray()
X_val = vectorizer.transform(val_texts).toarray()

# Convert labels to tensor
y_train = torch.tensor(train_labels.values)
y_val = torch.tensor(val_labels.values)

# Calculate class weights
class_weights = compute_class_weight(
    'balanced',
    classes=np.array(list(label_mapping.values())),  # Convert list to numpy array
    y=y_train.numpy()  # Ensure y_train is a tensor and convert to numpy
)

# Convert class_weights to a tensor for use in the model
class_weights = torch.tensor(class_weights, dtype=torch.float32)

# LSTM Model Definition
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Assuming x has shape (batch_size, sequence_length, input_dim)
        lstm_out, (hn, cn) = self.lstm(x)
        out = self.fc(hn[-1])
        return out

# Reshape input data to match LSTM's expected shape (batch_size, sequence_length, input_dim)
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)  # Adding sequence_length dimension
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).unsqueeze(1)  # Adding sequence_length dimension

# Define model, loss function, and optimizer
input_dim = X_train_tensor.shape[2]  # Updated to match input feature dimension
hidden_dim = 128
output_dim = len(label_mapping)
model = LSTMModel(input_dim, hidden_dim, output_dim)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training Loop
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train)

    # Backward pass and optimization
    loss.backward()
    optimizer.step()

    # Print loss every 2 epochs
    if (epoch + 1) % 2 == 0:
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}")

# Evaluation
model.eval()
with torch.no_grad():
    # Predictions on validation set
    val_outputs = model(X_val_tensor)
    _, predicted = torch.max(val_outputs, 1)

    # Metrics
    accuracy = accuracy_score(y_val, predicted)
    precision, recall, f1, _ = precision_recall_fscore_support(y_val, predicted, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

    # Classification report
    print("\nClassification Report:")
    target_names = list(label_mapping.keys())
    print(classification_report(y_val, predicted, target_names=target_names))

    # Confusion matrix
    cm = confusion_matrix(y_val, predicted)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names, cbar=False)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.tight_layout()
    plt.savefig(f'{drive_model_dir}/confusion_matrix.png')
    plt.show()

# Save model
torch.save(model.state_dict(), f'{drive_model_dir}/lstm_model.pth')
torch.save(vectorizer, f'{drive_model_dir}/vectorizer.pkl')

# Save training results
with open(f'{drive_model_dir}/classification_report.txt', 'w') as f:
    f.write(classification_report(y_val, predicted, target_names=target_names))

print("\n✅ Model, vectorizer, and evaluation saved to Google Drive.")
# Out:
# Epoch [2/10], Loss: 1.0949
# Epoch [4/10], Loss: 1.0863
# Epoch [6/10], Loss: 1.0775
# Epoch [8/10], Loss: 1.0679
# Epoch [10/10], Loss: 1.0575
# Accuracy: 0.6519
# Precision: 0.7358, Recall: 0.6519, F1: 0.6799
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Positive       0.88      0.68      0.76     11605
#     Negative       0.61      0.65      0.63      4687
#      Neutral       0.25      0.53      0.34      2164
#
#     accuracy                           0.65     18456
#    macro avg       0.58      0.62      0.58     18456
# weighted avg       0.74      0.65      0.68     18456
# ✅ Model, vectorizer, and evaluation saved to Google Drive.

# %%
# !pip install gensim
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 12.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %% [markdown]
# LSTM + Word2Vec

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader
import os

# Setup
nltk.download('punkt')
# Download 'punkt_tab' for sentence tokenization
nltk.download('punkt_tab')

drive_model_dir = '/content/drive/MyDrive/UM_DS_2023/Project'
os.makedirs(drive_model_dir, exist_ok=True)

# Load dataset
df = pd.read_csv("labeled_bert_ready_All_Beauty.csv")
df = df[['lightly_cleaned_review', 'sentiment_label']].dropna()

# Encode labels
label_mapping = {label: idx for idx, label in enumerate(df['sentiment_label'].unique())}
df['label'] = df['sentiment_label'].map(label_mapping)

# Tokenization
df['tokens'] = df['lightly_cleaned_review'].apply(word_tokenize)

# Train-test split
train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# Train Word2Vec
sentences = train_data['tokens'].tolist()
w2v_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
embedding_dim = 100
max_len = 50

# Convert tokens to vectors
def tokens_to_vec(tokens, model, max_len):
    vectors = [torch.tensor(model.wv[word]) for word in tokens if word in model.wv]
    if len(vectors) == 0:
        vectors = [torch.zeros(embedding_dim)]
    seq = pad_sequence(vectors, batch_first=True)[:max_len]
    if seq.size(0) < max_len:
        pad = torch.zeros((max_len - seq.size(0), embedding_dim))
        seq = torch.cat([seq, pad], dim=0)
    return seq

# Dataset Class
class ReviewDataset(Dataset):
    def __init__(self, df, w2v_model):
        self.vectors = [tokens_to_vec(tokens, w2v_model, max_len) for tokens in df['tokens']]
        self.labels = df['label'].values

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.vectors[idx], self.labels[idx]

train_dataset = ReviewDataset(train_data, w2v_model)
val_dataset = ReviewDataset(val_data, w2v_model)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# Handle class imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(df['label']), y=train_data['label'].values)
class_weights = torch.tensor(class_weights, dtype=torch.float32)

# LSTM Model
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])

# Model setup
hidden_dim = 128
output_dim = len(label_mapping)
model = LSTMClassifier(embedding_dim, hidden_dim, output_dim)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training
num_epochs = 5
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(train_loader):.4f}")

# Evaluation
model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.tolist())
        all_labels.extend(y_batch.tolist())

# Accuracy and report
accuracy = accuracy_score(all_labels, all_preds)
report = classification_report(all_labels, all_preds, target_names=label_mapping.keys())
print(f"\nAccuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(report)

# Save report
with open(os.path.join(drive_model_dir, "classification_report_word2vec_lstm.txt"), "w") as f:
    f.write(report)

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(os.path.join(drive_model_dir, "confusion_matrix_word2vec_lstm.png"))
plt.show()

# Save model
torch.save(model.state_dict(), os.path.join(drive_model_dir, "word2vec_lstm_model.pth"))
w2v_model.save(os.path.join(drive_model_dir, "word2vec.model"))

print("\n✅ Model, Word2Vec, report, and confusion matrix saved to Google Drive.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Epoch 1/5, Loss: 0.9779
# Epoch 2/5, Loss: 0.6758
# Epoch 3/5, Loss: 0.5361
# Epoch 4/5, Loss: 0.4791
# Epoch 5/5, Loss: 0.4300
#
# Accuracy: 0.8224
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Positive       0.96      0.84      0.89     11605
#     Negative       0.84      0.81      0.82      4687
#      Neutral       0.44      0.78      0.56      2164
#
#     accuracy                           0.82     18456
#    macro avg       0.75      0.81      0.76     18456
# weighted avg       0.87      0.82      0.84     18456
# ✅ Model, Word2Vec, report, and confusion matrix saved to Google Drive.
